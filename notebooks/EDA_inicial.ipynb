# %%
import pandas as pd

caminho = "../data/raw/"
itens_prova = pd.read_csv("../data/raw/ITENS_PROVA_2024.csv", encoding="ISO-8859-1", sep=";")
participantes = pd.read_csv("../data/raw/PARTICIPANTES_2024.csv", encoding="ISO-8859-1", sep=";")
resultados = pd.read_csv("../data/raw/RESULTADOS_2024.csv", encoding="ISO-8859-1", sep=";")

print("\nITENS PROVA")
display(itens_prova)
print("\nPARTICIPANTES")
display(participantes)
print("\nRESULTADOS")
display(resultados)
# Out:
# ITENS PROVA
#       CO_POSICAO SG_AREA  CO_ITEM TX_GABARITO  CO_HABILIDADE  IN_ITEM_ABAN  \
# 0              6      LC   150678           E             20             0
# 1              7      LC    14475           D              1             0
# 2              7      LC    14475           D              1             0
# 3              7      LC    16575           A             16             0
# 4              7      LC    16575           A             16             0
# ...          ...     ...      ...         ...            ...           ...
# 5545         176      MT    17549           E              8             0
# 5546         176      MT    17549           E              8             0
# 5547         176      MT    27923           A             19             0
# 5548         176      MT    27923           A             19             0
# 5549         176      MT    76177           D              1             0
#
# ...
